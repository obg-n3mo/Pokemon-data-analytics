# %% [markdown]
# # Elo Rating for Pokemon TCG Majors since 2024

# %% [markdown]
# The goal of this project is to assign every player at major Pokemon TCG tournaments an Elo rating, using a similar algorithm to FIDE.
#
# The final output is a dataframe with each player's name and country in form of 'Joe Shmoe [US]' and their current Elo. It might be useful to separate first name, last name, and country later, but likely I can just merge this table with the roster in tableau.
#
# I'd like to use this to filter games to give a matchup chart of only players above a certain Elo.

# %%
from bs4 import BeautifulSoup
import pandas as pd
import requests
import re
import copy
import numpy as np

# %%
# Set the tournament name with the year and city of the regional

tournament = 'pokemon-bologna-2025'

previous_tournament = 'pokemon-portland-2025'

homepage = 'https://rk9.gg/event/' + tournament

elo_ratings = pd.read_csv('Elo_Ratings/updated_for_' + previous_tournament +'.csv', index_col=[0])
#elo_ratings = pd.DataFrame({}, columns = ["Name","Rating"])  #This creates an empty elo sheet

# %% [markdown]
# This fuction we have used before. It fetches the urls for the roster and the pairings from the rk9 homepage.

# %%
def get_rk9_urls(homepage):
    soup = BeautifulSoup(requests.get(homepage).text)

    tcg = soup.find("div", class_ = 'card h-100 mt-3 p-2 shadow bg-blue-050') # Locate tcg box

    # Find url extensions for roster and pairings
    roster_code = tcg.find('a', {'href': re.compile('/roster*')})['href']  
    pairings_code = tcg.find('a', {'href': re.compile('/pairings*')})['href']

    roster_url = 'https://rk9.gg' + roster_code
    pairings_url = 'https://rk9.gg' + pairings_code
    
    return [roster_url,pairings_url]

# %% [markdown]
# We'll use a slightly simplified version of the FIDE agorithm for calculating elo. FIDE adjusts the value of k based on historical number of games played, which I am currently not recording, as well as adjusting it for high Elo players so their ranking is not too volatile. I may implement these changes in the future.

# %%
def update_elo(p1_rating, p2_rating, p1_result): # For p1_result, p1 wins : 1, tie : 0.5 , p1 loses : 0

    k = 32 #Might want to make this dynamic
    
    if type(p1_result) == float: # this deals with an issue cause by double game loss penalties

        prob_p1_wins = 1/(1 + 10**((p2_rating - p1_rating)/400))
        #prob_p2_wins = 1 - prob_p1_wins

        p1_rating_gain = k*(p1_result - prob_p1_wins)

        p1_rating += p1_rating_gain
        p2_rating -= p1_rating_gain

        return [p1_rating, p2_rating]  #Should ties not count?
    
    else:
        return [p1_rating, p2_rating]

# %%
def run_event(homepage, elo_ratings):
    
    # Get the pairings from rk9
    
    pairings_url = get_rk9_urls(homepage)[1]
    
    total_soup = BeautifulSoup(requests.get(pairings_url).text)
    total_rounds = int(total_soup.find_all('a', id = re.compile('P2R*'))[-2].text[1:])
    
    #total_rounds = 2
    
    for round_number in range(1, total_rounds+1):
        print('running round ' + str(round_number))
        pairing_soup = BeautifulSoup(requests.get(pairings_url, {'pod' : '2', 'rnd' : str(round_number)}).text)
    
        # Set up games as a list of the games played, and set a list of player 1 and player 2 for all games.

        games = pairing_soup.find_all('div', class_ = "row row-cols-3 match no-gutter complete")
        P1_names = [game.find('span', class_ = 'name').text for game in games]
        P2_names = [game.find_all('span', class_ = 'name')[-1].text for game in games]

        # Grab the match results, and deal with dropped players

        P1_result = [game.find('div', class_ = re.compile("col-5 text-center player*"))['class'][-1] for game in games]
        for i in range(len(P1_result)):
            game = games[i]
            if P1_result[i] == 'dropped':
                P1_result[i] = game.find('div', class_ = re.compile("col-5 text-center player*"))['class'][4]
                
            if P1_result[i] == 'dropped':
                P1_result[i] = 'double game loss'

        # Generate a DataFrame for the round

        round_dict = {
            'Player 1' : P1_names,
            'Player 2' : P2_names,
            'Result' : P1_result
            }

        round_df = pd.DataFrame(round_dict)

        # Remove players that didn't play

        mask = (round_df['Player 1'] == round_df['Player 2'])
        round_df = round_df[~mask]

        # Convert 'winner', 'loser', or 'tie' to 1, 0, or 0.5

        round_df.loc[round_df['Result'] == "loser",'Result'] = 0.0
        round_df.loc[round_df['Result'] == "winner",'Result'] = 1.0
        round_df.loc[round_df['Result'] == 'tie', 'Result'] = 0.5

        # Convert the Dataframe back to 3 lists (Probably didn't need to bother with the df...)

        p1_list = round_df['Player 1'].to_list()
        p2_list = round_df['Player 2'].to_list()
        result_list = round_df['Result'].to_list()

        new_players = []  # To store unranked players

        

        for match in range(len(round_df)):  # Iterate through the games in the round
            p1_new = False    # Assume players aren't new to start
            p2_new = False
            
            p1 = p1_list[match]
            p2 = p2_list[match]      # Set players and result
            
            #p1 = re.sub(r'^\*\S+\s*', '', p1)  # This fixes vip and fixed seating issues
            #p2 = re.sub(r'^\*\S+\s*', '', p2)  # this regex removes the first word if the string starts with *
            
            #p1 = re.sub(r'^\*\S+\s+\S+\s*', '', p1)  
            #p2 = re.sub(r'^\*\S+\s+\S+\s*', '', p2)  # this regex removes the first 2 words if the string starts with *
            
            #p1 = re.sub(r'^\[[^]]*\]\s*', '', p1)  #They changed how they represent static and vip seating..
            #p2 = re.sub(r'^\[[^]]*\]\s*', '', p2)  #this regex removes the first [...] if its at the start of the string
            
            #p1 = re.sub(r'>[^>]*>\s?', '', p1)
            #p2 = re.sub(r'>[^>]*>\s?', '', p2) #this regex removes anything enlosed in > >
            
            #p1 = re.sub(r'^>\S+\s*', '', p1)
            #p2 = re.sub(r'^>\S+\s*', '', p2) # removes the first word if the string starts with >
            
            #p1 = re.sub(r'^#\S+\s*', '', p1)
            #p2 = re.sub(r'^#\S+\s*', '', p2) # removes the first word if the string starts with #
            
            #p1 = re.sub(r'^>\S+\s+\S+\s*', '', p1)  
            #p2 = re.sub(r'^>\S+\s+\S+\s*', '', p2)  # removes the first 2 words if the string starts with >
            
            #p1 = re.sub(r'\d+', '', p1)
            #p2 = re.sub(r'\d+', '', p2) #removes numbers
            
            #p1 = re.sub(r'^>\s*\S+\s*', '', p1)
            #p2 = re.sub(r'^>\s*\S+\s*', '', p2) #use this if the static seating looks like > 315 first last
            
            #p1 = re.sub(r'\bSTATIC SEATING\b|\([^)]*\)', '', p1).strip()
            #p2 = re.sub(r'\bSTATIC SEATING\b|\([^)]*\)', '', p2).strip() # for 'STATIC SEATING (30)'
            
            result = result_list[match]

            if p1 in elo_ratings.Name.values:  # This checks if the player is ranked yet

                                        # This checks if the player is a duplicate. We should only get a ValueError
                                        # if this is the case, but theres prob a cleaner way to handle this
                try:
                    old_p1_rating = elo_ratings.loc[elo_ratings['Name'] == p1, 'Rating'].item()
                except ValueError:
                    old_p1_rating = 'Duplicate'

            else:                 # Deals with new players
                p1_new = True
                old_p1_rating = 1000.0
                print(p1+' added to rankings')


            # All the same as for p1

            if p2 in elo_ratings.Name.values:
                try:
                    old_p2_rating = elo_ratings.loc[elo_ratings['Name'] == p2, 'Rating'].item()
                except ValueError:
                    old_p2_rating = 'Duplicate'
            else:
                p2_new = True
                old_p2_rating = 1000.0
                print(p2+' added to rankings')


            # For now we just can't rank duplicates
            
            if old_p1_rating == "Duplicate":
                new_p1_rating = "Duplicate"
                
            if old_p2_rating == "Duplicate":
                new_p2_rating = "Duplicate"


            if old_p1_rating != "Duplicate" and old_p2_rating != "Duplicate":

                new_ratings = update_elo(old_p1_rating, old_p2_rating, result) # Calc the new ratings

                new_p1_rating = new_ratings[0]
                new_p2_rating = new_ratings[1]

                # Assign ratings differently if they are new

                if p1_new:
                    new_players.append([p1, new_p1_rating])

                else:
                    elo_ratings.loc[elo_ratings['Name'] == p1, 'Rating'] = new_p1_rating
                if p2_new:
                    new_players.append([p2, new_p2_rating])
                else:
                    elo_ratings.loc[elo_ratings['Name'] == p2, 'Rating'] = new_p2_rating
                    
            
        # Turn the list of new players and their elos into a df, and concat with the full list

        new_players_df = pd.DataFrame(new_players,columns = ['Name', 'Rating'])
        
        #pattern = re.compile(r'^\*\S+\s*') # This fixes vip and fixed seating issues
        #new_players_df['Name'] = new_players_df['Name'].str.replace(pattern, '', regex=True)
        
        elo_ratings = pd.concat([elo_ratings, new_players_df],axis = 0,ignore_index = True)
        

    return elo_ratings

# %%
final_ratings = run_event(homepage, elo_ratings)
#final_ratings.to_csv('Elo_Ratings/updated_for_' + tournament +'.csv')
# Out:
# running round 1
# Giacomo Treppiedi [IT] added to rankings
# Manuel Giuseppe La Iacona [IT] added to rankings
# Elisa Piccolantonio [IT] added to rankings
# Graziano Piccone [IT] added to rankings
# Nathan VILLA [FR] added to rankings
# andrea minopoli [IT] added to rankings
# Nicola Bono [IT] added to rankings
# Nicola Poggiana [IT] added to rankings
# Jan Breznar [SI] added to rankings
# Luca Bandini [IT] added to rankings
# Gabriele Frantozzi [IT] added to rankings
# Alessio De Nicola [IT] added to rankings
# Serena Anna Iaconis [IT] added to rankings
# Alessandro Pula [IT] added to rankings
# Marco Pieroni [IT] added to rankings
# Daniele Iofalo [IT] added to rankings
# Jonny Maculan [IT] added to rankings
# Sebastiano Cantore [IT] added to rankings
# Alessandro Di Patrizio [IT] added to rankings
# Riccardo Rossetti [IT] added to rankings
# Roberta Buia [IT] added to rankings
# Samuele Ciardelli [IT] added to rankings
# Tommaso Falchi [IT] added to rankings
# Andrea Gilioli [IT] added to rankings
# Domenico Paladino [IT] added to rankings
# Giovanni Santuccio [IT] added to rankings
# Ciro Erco [IT] added to rankings
# Angelo camelliti [IT] added to rankings
# Niccolò Delpopolo [IT] added to rankings
# Michele Rizzato [IT] added to rankings
# Adriano D'Angelo [IT] added to rankings
# ENRICO BORTOLOTTI [IT] added to rankings
# Luigi Pezzoli [IT] added to rankings
# Matteo Desiato [IT] added to rankings
# Ottavio Carmelo [IT] added to rankings
# Tjaša Repič [SI] added to rankings
# Davide Panebianco [IT] added to rankings
# Sergio Ruffilli [IT] added to rankings
# Claudio Conforto [IT] added to rankings
# Giulia Gastaldello [IT] added to rankings
# Thomas Raich [DE] added to rankings
# Federico Pasquini [IT] added to rankings
# Manuel Massaro [IT] added to rankings
# Fernando Peró [IT] added to rankings
# Mario Imaprato [IT] added to rankings
# Ettore Boccignone [IT] added to rankings
# Eilai Neira Mercedes [IT] added to rankings
# Francesco Maria Parlati [IT] added to rankings
# Samuel Bonizzi [IT] added to rankings
# Sylvia Fuentelsaz [ES] added to rankings
# melina aydan yumer [IT] added to rankings
# Diego Viganò [IT] added to rankings
# Alessandro Valenti [IT] added to rankings
# Noemi Magnani [IT] added to rankings
# Pierfrancesco Lupo [IT] added to rankings
# Yves Spangenberg [PL] added to rankings
# Pasquale Giuseppe Zavatta [IT] added to rankings
# Jeremia Mihajlovic [IT] added to rankings
# Simone Cappeller [IT] added to rankings
# Erwan Leborgne [FR] added to rankings
# Lorenzo Ferilli [CH] added to rankings
# Andrea Vandini [IT] added to rankings
# Fabio Zotti [IT] added to rankings
# Andrea Marcassoli [IT] added to rankings
# Samuele Gonella [IT] added to rankings
# Luca Munerotto [IT] added to rankings
# Luca Fortuna [IT] added to rankings
# Denni Bevilacqua [IT] added to rankings
# Dante Ippolito [IT] added to rankings
# Luca Carniani [IT] added to rankings
# giovanni cecere [IT] added to rankings
# Mattia Bichi [IT] added to rankings
# Sebastiano Tognetti [IT] added to rankings
# Massimo Jacopo Favaretto [IT] added to rankings
# marco Anziliero [IT] added to rankings
# Emanuel Buonincontri [IT] added to rankings
# Matthias Riess [AT] added to rankings
# Jason Welke [DE] added to rankings
# Luca Ginex [IT] added to rankings
# Luca Buosi [IT] added to rankings
# Tommaso Serra [IT] added to rankings
# Modesto Bellipario [IT] added to rankings
# giuseppe vitti [IT] added to rankings
# Patrik Tkalec [HR] added to rankings
# Vittorio Sommatino [IT] added to rankings
# andrea huang [IT] added to rankings
# Davide Amadei [IT] added to rankings
# Corrado Ricupero [IT] added to rankings
# Luca Pernel [IT] added to rankings
# lorenzo chiarato [IT] added to rankings
# Aljaž Žel [SI] added to rankings
# Cristian Grosu [IT] added to rankings
# Arnau Gómez Amate [ES] added to rankings
# Leonardo Scarsella [IT] added to rankings
# Oliver Statua [IT] added to rankings
# Marco De Lucia [IT] added to rankings
# Andrea Lorenzini [IT] added to rankings
# enrico licciardello [IT] added to rankings
# Cristian Lazzaroni [IT] added to rankings
# Alberto Scannaliato [IT] added to rankings
# Michael Pace [IT] added to rankings
# Gaetano Quartaronello [IT] added to rankings
# Paolo Ciccotto [IT] added to rankings
# Luca Colosso [IT] added to rankings
# Marcello Santini [IT] added to rankings
# Francesco Alessandro Maria Napolitano [IT] added to rankings
# Ciro Pascale [IT] added to rankings
# Thomas Ponthieux [IT] added to rankings
# Carmine Cusati [IT] added to rankings
# Marco Ferrara [IT] added to rankings
# Francesco Paolo Tomaiuolo [IT] added to rankings
# Graziano Carmelo [IT] added to rankings
# Stefano Ottaviani [IT] added to rankings
# Marco Passantino [IT] added to rankings
# Elia Gentili [IT] added to rankings
# Lorenzo Salvatore [IT] added to rankings
# Loris Passerini [IT] added to rankings
# tommaso sponziello [IT] added to rankings
# Niccolò Lopez [IT] added to rankings
# lorenzo lensi [IT] added to rankings
# Mattia Belloni [IT] added to rankings
# Tommaso Vinciguerra [IT] added to rankings
# Sara Pangrazi [IT] added to rankings
# Vincenzo Pendolino [IT] added to rankings
# federico stagi [IT] added to rankings
# Federico Rampinelli [IT] added to rankings
# Nicola benedetto Torraca [IT] added to rankings
# Emanuele Mazzoleni [IT] added to rankings
# Giacomo Goberti [IT] added to rankings
# Gabriele Stringano [IT] added to rankings
# Andrea Fuga [IT] added to rankings
# Federico Fornasari [IT] added to rankings
# Federico Antonelli [IT] added to rankings
# Francesco Baiocchi [IT] added to rankings
# Gabriele Signorino [IT] added to rankings
# Alessandro Pardo [IT] added to rankings
# Nicolò Zardo [IT] added to rankings
# Michele Munari [IT] added to rankings
# Matteo Lampugnano [IT] added to rankings
# Alessio Parma [IT] added to rankings
# Ivan Denti [IT] added to rankings
# Fabio Giovannetti [IT] added to rankings
# Niccolò Catalani [IT] added to rankings
# hans peter sacramento paling [IT] added to rankings
# Erasmo Luca Giovanniello [IT] added to rankings
# Gergely Mogyorósi [HU] added to rankings
# Fabrizio Majolino [IT] added to rankings
# Antonio Fera [IT] added to rankings
# Alessandro Giuliano [IT] added to rankings
# Filippo Rosati [IT] added to rankings
# Davide Livietti [IT] added to rankings
# Marco Matarazzi [IT] added to rankings
# Gabriele Castaldo [IT] added to rankings
# Stefano Sebellin [IT] added to rankings
# Kacper Jankowski [PL] added to rankings
# Simone Checcucci [IT] added to rankings
# Cristian Marruso [IT] added to rankings
# Andrea Milesi [IT] added to rankings
# Alex Zazzetta [IT] added to rankings
# Lorenzo Vannoni [IT] added to rankings
# Stephano Carlomagno [IT] added to rankings
# Michel Bressan [IT] added to rankings
# Valerio Bertaccini [IT] added to rankings
# Leonardo Bambini [IT] added to rankings
# Andrea Pivetti [IT] added to rankings
# Salvatore Lio [IT] added to rankings
# EMANUELE VITO LA PIANA [IT] added to rankings
# Alessandro Tafuri [IT] added to rankings
# Timotej Grabušnik [SI] added to rankings
# Luca Nasso [IT] added to rankings
# Francesco Lazzaroni [IT] added to rankings
# Sebastjan Bagon [IT] added to rankings
# Pierluigi Barocci [IT] added to rankings
# Marco Escher [IT] added to rankings
# Mattia Lisciandrello [IT] added to rankings
# Roberto Rescigno [IT] added to rankings
# Alberto Facondini [IT] added to rankings
# Matteo Francesco Macheda [IT] added to rankings
# Cesare Campo [IT] added to rankings
# Alessandro Cattaneo [IT] added to rankings
# Francesco Morini [IT] added to rankings
# Filippo Schierato [IT] added to rankings
# Cristian D'Aversa [IT] added to rankings
# Katia Barth [CH] added to rankings
# Alberto Nesca [IT] added to rankings
# Marco Perilli [IT] added to rankings
# Giammarco Cordaro [IT] added to rankings
# Marco Chiudaroli [IT] added to rankings
# Maurizio Mori [IT] added to rankings
# Sara Baraldi [IT] added to rankings
# Pietro Malevolti [IT] added to rankings
# Daniel Otero Menduiña [ES] added to rankings
# Antonio Cannavacciuolo [IT] added to rankings
# Branco Arbini [IT] added to rankings
# Gianluca Strano [IT] added to rankings
# Andrea Vallesi [IT] added to rankings
# Simone Delmonte [IT] added to rankings
# Silvia Taroni [IT] added to rankings
# Julian Johannes Kriegesmann [DE] added to rankings
# Simone Orante [IT] added to rankings
# Marco Taroni [IT] added to rankings
# Francesco Cangelosi [IT] added to rankings
# Max Prokopov [BG] added to rankings
# Noah Martínez Senserrich [ES] added to rankings
# Mattia Stragliotto [IT] added to rankings
# Matteo Di Nardo [IT] added to rankings
# Lorenzo Bottani [IT] added to rankings
# Christian Gozzolino [IT] added to rankings
# Carlo Mancini [IT] added to rankings
# Domenico Prencipe [IT] added to rankings
# Andrea Cristiano Maria Napolitano [IT] added to rankings
# Daniele Malusardi [IT] added to rankings
# Rachel Cangini [IT] added to rankings
# Giulia Orlandi [IT] added to rankings
# Mirko Bossi [CH] added to rankings
# Luca Carolo [IT] added to rankings
# Diego Ribeiro Videira [IT] added to rankings
# Michele Musolino [IT] added to rankings
# Erik Schetters [DE] added to rankings
# Paolo Varbaro [IT] added to rankings
# Gaetano Granata [IT] added to rankings
# Justin Robert Welke [DE] added to rankings
# Vittorio Ruffinengo [IT] added to rankings
# Lorenzo Contu [IT] added to rankings
# Mirco Quatrale [IT] added to rankings
# Marica Rossi [IT] added to rankings
# Valerio Carista [IT] added to rankings
# Filippo Succi [IT] added to rankings
# Lapo Lepri [IT] added to rankings
# leonardo Giannotta [IT] added to rankings
# Matteo Bonginelli [IT] added to rankings
# Davide Berrino [IT] added to rankings
# Alessandro Laudini [IT] added to rankings
# Marwan ATTOBI [FR] added to rankings
# Tommaso Foresi [IT] added to rankings
# Francesco Festa [IT] added to rankings
# Michele Fabiano [IT] added to rankings
# Leonardo Benassi [IT] added to rankings
# Lorenzo Tolotti [IT] added to rankings
# Manuel Piccardi [IT] added to rankings
# Davide Abbondandolo [IT] added to rankings
# Rob Bartlett [UK] added to rankings
# Emanuele Perrone Guerzoni [IT] added to rankings
# Pasquale Porrari [IT] added to rankings
# Alessandro De Marco [IT] added to rankings
# Luigi Zuccarelli [IT] added to rankings
# Ivan Kalajdžić [HR] added to rankings
# Massimiliano Cantini [IT] added to rankings
# Daniele Dall'Asta [IT] added to rankings
# Martina Balmelli [IT] added to rankings
# Francesco Saverio Palumbo [IT] added to rankings
# Roberto Lenisa [IT] added to rankings
# Laura Weinhart [DE] added to rankings
# Matteo Doda [IT] added to rankings
# Emanuele Benedini [IT] added to rankings
# Matteo Cavallo [IT] added to rankings
# Luigi Bautista [IT] added to rankings
# Federico Mascolo [IT] added to rankings
# Gianfilippo Cattelan [IT] added to rankings
# Andrea Zanini [IT] added to rankings
# alessandro blanda [IT] added to rankings
# Alessio Comparozzi [IT] added to rankings
# Daniele Gasperi [IT] added to rankings
# Veronica Pallanza [IT] added to rankings
# Gianluca Cipriano [IT] added to rankings
# JOELE BRACONE [IT] added to rankings
# nicolò mario sironi [IT] added to rankings
# Gian Marco Morigi [IT] added to rankings
# Yasmine Chakiri [IT] added to rankings
# Marco Iandelli [IT] added to rankings
# Lorenzo Repetto [IT] added to rankings
# Matteo Ziccarelli [IT] added to rankings
# Gennaro Petito [IT] added to rankings
# Giuseppe Minino [IT] added to rankings
# Paolo Miroballi [IT] added to rankings
# Gioele Ciamaglia [IT] added to rankings
# Paolo Aparo [IT] added to rankings
# Lorenzo Litro [IT] added to rankings
# Andrea Sironi [IT] added to rankings
# Lorenzo Ciberti [IT] added to rankings
# Luca Gaspari [IT] added to rankings
# Federico D'Orazio [IT] added to rankings
# Alexandru Pricop [IT] added to rankings
# Davide Piluscio [IT] added to rankings
# Cristina Pelizza [IT] added to rankings
# Valentina Zambon [IT] added to rankings
# Luca Rosato [IT] added to rankings
# Jan Kousal [CZ] added to rankings
# Mattia Martinelli [IT] added to rankings
# Alessandro Falcone [IT] added to rankings
# Miguel Flor S. [EC] added to rankings
# Alberto Fragapane [IT] added to rankings
# Marco Matteini [IT] added to rankings
# Sasha Raimo [IT] added to rankings
# Giovanni Bertelli [IT] added to rankings
# Alexandru Rat [IT] added to rankings
# Nicholas Felitti [IT] added to rankings
# Lucian Cucu [IT] added to rankings
# Stefano Rensi [IT] added to rankings
# Claudio Filippone [IT] added to rankings
# Yuri Senaldi [IT] added to rankings
# Luca Sciutto [IT] added to rankings
# Gabriele Bricola [IT] added to rankings
# Giacomo Sarti [IT] added to rankings
# Gianluca Commissari [IT] added to rankings
# Mirko Sorbetti [IT] added to rankings
# Francesco Limongi Concetto [IT] added to rankings
# Dominik Bielinski [IT] added to rankings
# Daniel Schifano [IT] added to rankings
# Riccardo Mandioni [IT] added to rankings
# Giovanni Vettore [IT] added to rankings
# Valentina Carubia [IT] added to rankings
# Pablo Dorado [ES] added to rankings
# samuele reggiani [IT] added to rankings
# Davide Mancini [IT] added to rankings
# Andrea Sodaro [IT] added to rankings
# Letícia Vieira Silva [BR] added to rankings
# Gleb Kastsianevich [IT] added to rankings
# Mattia Fornaro [IT] added to rankings
# Marco Casciana [IT] added to rankings
# Manuel Antonio Romero Venegas [ES] added to rankings
# Pierpaolo D'Elicio [IT] added to rankings
# Simone Lugli [IT] added to rankings
# Giacomo Trapani [IT] added to rankings
# Samuele Sivieri [IT] added to rankings
# Alessandro Cannarozzi [IT] added to rankings
# Francesco Casamassima [IT] added to rankings
# Octavian Stegarescu [IT] added to rankings
# Lorenzo Murzilli [IT] added to rankings
# Danilo Rotella [IT] added to rankings
# Nicolò Pace [IT] added to rankings
# Marco Tolasi [IT] added to rankings
# Salvatore Imbergamo [IT] added to rankings
# Mattia Carli [IT] added to rankings
# Simone Spitale [IT] added to rankings
# Samuele Pesciaioli [IT] added to rankings
# Lorenzo Cuoco [IT] added to rankings
# Adriel Suriano [IT] added to rankings
# Fulvio Mura [IT] added to rankings
# Mauro Brisacani [IT] added to rankings
# Devid Sabli [IT] added to rankings
# christian gomitoli [IT] added to rankings
# John Michael Ramil [IT] added to rankings
# Andrea Bianchi [IT] added to rankings
# Marco Barbieri [IT] added to rankings
# Davide Mondin [IT] added to rankings
# Filippo Marucci [IT] added to rankings
# Gabriele Cammarata [IT] added to rankings
# Francesco Rencinai [IT] added to rankings
# Giuseppe Nacci [IT] added to rankings
# Cesare Del Bonifro [IT] added to rankings
# Mateusz Kwiatosz [IT] added to rankings
# Lorenzo Patrizi [IT] added to rankings
# haizea monje added to rankings
# Andrea Maccalli [IT] added to rankings
# Ainhoa Ramírez [ES] added to rankings
# Antonio Granata [IT] added to rankings
# Sergio Falcone [IT] added to rankings
# Ivano Caricchia [IT] added to rankings
# Edoardo Allavena [IT] added to rankings
# Davide Pasini [IT] added to rankings
# Carlo Serra [IT] added to rankings
# Christian Alasia [IT] added to rankings
# Alessandro Godani [IT] added to rankings
# Shansha Mannan [IT] added to rankings
# Emanuele Materassi [IT] added to rankings
# Nadia Parenti [IT] added to rankings
# Kristian Pirani [IT] added to rankings
# Lorenzo Orlandi [IT] added to rankings
# Antonio Di Palma [IT] added to rankings
# Pietro Aldighieri [IT] added to rankings
# Rafał Kozielski vel Koziak [PL] added to rankings
# Andrea Sergas [IT] added to rankings
# Giovanni Gattazzo [IT] added to rankings
# Alexander Quispe Chacon [IT] added to rankings
# Matteo Negro [IT] added to rankings
# Alberto Califano [IT] added to rankings
# Daniel Rogato [IT] added to rankings
# Andrea Cannarozzi [IT] added to rankings
# Salvatore Polverino [IT] added to rankings
# Andrea Panebianco [IT] added to rankings
# Pietro Luciani [IT] added to rankings
# Mirko Gurian [IT] added to rankings
# Marco Specchia [IT] added to rankings
# Alessio Ferrante [IT] added to rankings
# Lorenzo Ceragioli [IT] added to rankings
# Leonardo Orfani [IT] added to rankings
# mohamed amin seradouni [IT] added to rankings
# Stefano Del Conte [IT] added to rankings
# Paolo De Marinis [IT] added to rankings
# Laura Pintor [IT] added to rankings
# Fabio Tatananni [IT] added to rankings
# Marco Ventimiglia [IT] added to rankings
# Richard Hochauer [AT] added to rankings
# Francesco Paolo Palumbo [IT] added to rankings
# Giovanni Magliano [IT] added to rankings
# Daniele Amodio [IT] added to rankings
# Valerio Basile [IT] added to rankings
# Lorenzo Marchese [IT] added to rankings
# Andrea Abele Pellegrino [IT] added to rankings
# Lorenzo Bottero [IT] added to rankings
# Antonella Castria [IT] added to rankings
# Cristiano Longordo [IT] added to rankings
# Andrea Bertani [IT] added to rankings
# Patrizio Usai [IT] added to rankings
# Lorenzo Guglielmi [IT] added to rankings
# Anna Zamora Caballero [ES] added to rankings
# Sara Pianelli [IT] added to rankings
# Matteo Amadori [IT] added to rankings
# Federico Agnello [IT] added to rankings
# Simone Torre [IT] added to rankings
# Martin Bartos [AT] added to rankings
# Stefano Capelli [IT] added to rankings
# Ernesto Leon Hector Gagliardi [IT] added to rankings
# Manuele Carraturo [IT] added to rankings
# Michele Pio Lillo [IT] added to rankings
# Filippo Chierici [IT] added to rankings
# Riccardo Borri [IT] added to rankings
# Paolo Palombi [IT] added to rankings
# Amedeo Abbondanza [IT] added to rankings
# Andrea Picasso [IT] added to rankings
# Michael Meazzo [IT] added to rankings
# Mihaela Maric [HR] added to rankings
# Davide Surace [IT] added to rankings
# Gabriele Amore [IT] added to rankings
# Patrick Peter [IT] added to rankings
# Francesco Destino [IT] added to rankings
# Matteo Rabacchi [IT] added to rankings
# Federico Casamassima [IT] added to rankings
# Nicholas Maieron [IT] added to rankings
# Francesco Muroni [IT] added to rankings
# Maurizio Gozzi [IT] added to rankings
# Matteo Caldaroni [IT] added to rankings
# Fin Peters [UK] added to rankings
# Giacomo Burzi [IT] added to rankings
# Alessio Marchetti [IT] added to rankings
# Chiara Martinis [IT] added to rankings
# Diego Ebau [IT] added to rankings
# Aaron Dall'Era [IT] added to rankings
# Santiago de Saussure [CH] added to rankings
# Daniele Ricci [IT] added to rankings
# Gianluca Sarcina [IT] added to rankings
# Gabriele Pula [IT] added to rankings
# Tommaso Napolitano [IT] added to rankings
# Diego Battistini [IT] added to rankings
# Alessandro Cagliano [IT] added to rankings
# Francesco Cimmino [IT] added to rankings
# Carmine Scaglione [IT] added to rankings
# Paolo Antinori [IT] added to rankings
# Gabriele Garcina [IT] added to rankings
# Emanuele Seghetti [IT] added to rankings
# manuel domenici [IT] added to rankings
# Gabriele Borghetti [IT] added to rankings
# alex birzu [IT] added to rankings
# Pietro Piazze [IT] added to rankings
# Francesco Nardi [IT] added to rankings
# lorenzo demichele [IT] added to rankings
# Manuel Ianzito [IT] added to rankings
# Matteo Debernardis [IT] added to rankings
# Riccardo Cupini [IT] added to rankings
# Luca Tesini [IT] added to rankings
# Ivan Sokolov [IT] added to rankings
# SAMUEL MENUT [FR] added to rankings
# Claudio Esposito [IT] added to rankings
# Federico Terraneo [IT] added to rankings
# Francesca Sonzogni [IT] added to rankings
# Gianfranco Romeo [IT] added to rankings
# Riccardo Vecchiato [IT] added to rankings
# Valerio Pompili [IT] added to rankings
# Sandro Presta [IT] added to rankings
# Tommaso Parcesepe [IT] added to rankings
# Kevin Raineri Russo [IT] added to rankings
# Filippo Ferrari [IT] added to rankings
# running round 2
# Luca Capodiferro added to rankings
# Michael Monteleone added to rankings
# Daniele Bertoncini added to rankings
# Davide Massaro added to rankings
# running round 3
# running round 4
# running round 5
# running round 6
# running round 7
# running round 8
# running round 9
# running round 10
# running round 11
# running round 12
# running round 13
# running round 14
# running round 15

# %%
final_ratings[final_ratings['Rating'] >= 1350]
# Out:
#                             Name       Rating
# 73              Abaan Ahmed [US]  1423.396623
# 157             Tord Reklev [NO]  1355.197925
# 648       Sebastian Lashmet [US]  1391.909109
# 759          Isaiah Bradner [US]  1392.071009
# 798          Caleb Rogerson [US]  1450.537702
# 833          Andrew Hedrick [US]  1386.503092
# 896        Michael Davidson [US]  1432.432443
# 915         Alex Schemanske [US]  1391.206703
# 925              Lucas Xing [CA]  1415.672654
# 1075             Grant Shen [US]  1366.346494
# 1261             Dylan Gunn [US]  1381.815643
# 1624      Christian LaBella [CA]  1436.290419
# 1684         Rowan Stavenow [CA]  1354.759452
# 1716          Hasan Kunukcu [US]  1354.752911
# 1756                Jon Eng [US]  1391.959404
# 1968          Aarni Karjala [FI]  1361.169098
# 2027           Oscar Madsen [DK]  1377.164207
# 2101       Julius Brunfeldt [FI]  1354.508154
# 2348          Pedro Pertusi [BR]  1393.437377
# 2382    Fabrizio Inga Silva [PE]  1358.395964
# 2412     Vinícius fernandez [BR]  1369.336959
# 2514        William Azevedo [BR]  1374.889736
# 3565         Brent Tonisson [AU]  1488.942863
# 3806           Piper Lepine [US]  1404.308866
# 4673            Makani Tran [US]  1383.908730
# 5036         Noah Sakadjian [US]  1353.753025
# 5145      Öjvind Svinhufvud [FI]  1363.384413
# 5153        Yoann Barszezak [FR]  1399.329038
# 5452     Christian Fontenot [DK]  1398.767101
# 5569         Bryan de Vries [NL]  1352.770949
# 5803          Caitlin White [CA]  1397.846916
# 8616           Simon Tschan [CH]  1378.189325
# 9594   Julio Santos De Leon [US]  1365.246855
# 11194            Henry Chao [US]  1421.559042
# 14696        NATALIE Millar [AU]  1365.160423
# 20340          Owen Dalgard [US]  1397.309409

# %%
final_ratings = final_ratings.drop_duplicates(subset = 'Name', keep = False)
final_ratings
# Out:
#                         Name       Rating
# 0          Aaron Walker [US]  1201.293823
# 1      Jimmy Wellington [US]   936.000000
# 2        Cassidy Gibson [US]   996.628463
# 3        Kenneth Mauder [US]  1236.549829
# 4           Jacob Henry [US]   892.906995
# ...                      ...          ...
# 33670   Filippo Ferrari [IT]   981.275649
# 33671       Luca Capodiferro   986.661861
# 33672     Michael Monteleone   995.788140
# 33673     Daniele Bertoncini  1045.003199
# 33674         Davide Massaro  1013.053229
#
# [33675 rows x 2 columns]

# %%
final_ratings.to_csv('Elo_Ratings/updated_for_' + tournament +'.csv')
